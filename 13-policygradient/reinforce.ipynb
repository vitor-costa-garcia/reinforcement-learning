# %%
import torch
from torch import nn
import numpy as np
import gymnasium as gym

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(4, 64),
            nn.ReLU(),
            nn.Linear(64, 2),
            nn.Softmax(dim=-1)
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

DF = 0.99
LR = 0.01
model = NeuralNetwork().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = LR)

def training_loop_REINFORCE(epochs):
    global model
    global optimizer
    env = gym.make("CartPole-v1")

    for ep in range(epochs):
        terminated = truncated = False
        episode = []
        obs, _ = env.reset()

        while not (terminated or truncated):
            logits = model(torch.tensor(obs))
            dist = torch.distributions.Categorical(logits)
            action = dist.sample()
            log_prob = dist.log_prob(action)

            old_obs = obs
            obs, reward, terminated, truncated, _ = env.step(action.item())
            episode.append((old_obs, action, reward, log_prob))

        returns = []
        G = 0
        for _, _, reward, _ in reversed(episode):
            G = reward + DF * G
            returns.insert(0, G)

        returns = torch.tensor(returns, dtype=torch.float32, device=device)
        returns = (returns - returns.mean()) / (returns.std(unbiased=False) + 1e-8)

        # Compute loss
        loss = 0
        for (_, _, _, log_prob), G in zip(episode, returns):
            loss += -log_prob * G

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        print(f"Episode {ep+1}, loss={loss.item():.4f}")

    env.close()

def testing_loop_REINFORCE(epochs):
    global model
    global optimizer
    env = gym.make("CartPole-v1", render_mode="human")
    obs, _ = env.reset()

    for ep in range(epochs):
        terminated = truncated = False

        while not (terminated or truncated):
            logits = model(torch.tensor(obs))
            dist = torch.distributions.Categorical(logits)
            action = dist.sample()

            obs, _, terminated, truncated, _ = env.step(action.item())

    env.close()
# Out:
# Using cpu device

# %%
training_loop_REINFORCE(300)
LR = 0.001
training_loop_REINFORCE(100)
LR = 0.0001
training_loop_REINFORCE(100)
# Out:
# Episode 1, loss=0.2029
# Episode 2, loss=0.1983
# Episode 3, loss=0.4970
# Episode 4, loss=-0.6761
# Episode 5, loss=-0.1370
# Episode 6, loss=-0.7056
# Episode 7, loss=-0.0431
# Episode 8, loss=-0.0916
# Episode 9, loss=0.0454
# Episode 10, loss=-1.7428
# Episode 11, loss=0.3668
# Episode 12, loss=0.4730
# Episode 13, loss=-2.7938
# Episode 14, loss=-0.0422
# Episode 15, loss=1.2884
# Episode 16, loss=-0.2788
# Episode 17, loss=1.8216
# Episode 18, loss=0.7543
# Episode 19, loss=-3.9014
# Episode 20, loss=1.0946
# Episode 21, loss=0.4778
# Episode 22, loss=0.3583
# Episode 23, loss=0.4806
# Episode 24, loss=-0.9957
# Episode 25, loss=0.1514
# Episode 26, loss=-0.0561
# Episode 27, loss=0.7286
# Episode 28, loss=-0.6525
# Episode 29, loss=-0.6882
# Episode 30, loss=-1.2162
# Episode 31, loss=0.6176
# Episode 32, loss=-0.1195
# Episode 33, loss=-0.5412
# Episode 34, loss=-0.5497
# Episode 35, loss=1.4280
# Episode 36, loss=1.8412
# Episode 37, loss=0.9333
# Episode 38, loss=0.6575
# Episode 39, loss=-0.5315
# Episode 40, loss=0.2421
# Episode 41, loss=0.2772
# Episode 42, loss=0.7840
# Episode 43, loss=-1.6569
# Episode 44, loss=-0.3810
# Episode 45, loss=3.1794
# Episode 46, loss=-1.7150
# Episode 47, loss=-0.3673
# Episode 48, loss=0.9116
# Episode 49, loss=0.5600
# Episode 50, loss=-0.0673
# Episode 51, loss=1.2853
# Episode 52, loss=-1.2467
# Episode 53, loss=-1.3554
# Episode 54, loss=-2.5522
# Episode 55, loss=2.2484
# Episode 56, loss=-0.8557
# Episode 57, loss=1.3970
# Episode 58, loss=-2.6837
# Episode 59, loss=-0.5277
# Episode 60, loss=-3.9209
# Episode 61, loss=2.3233
# Episode 62, loss=-1.6261
# Episode 63, loss=2.2308
# Episode 64, loss=-0.2752
# Episode 65, loss=4.9292
# Episode 66, loss=-0.0917
# Episode 67, loss=-3.5186
# Episode 68, loss=-4.6623
# Episode 69, loss=-0.3087
# Episode 70, loss=0.3310
# Episode 71, loss=-3.3880
# Episode 72, loss=-6.5763
# Episode 73, loss=0.5252
# Episode 74, loss=-1.3925
# Episode 75, loss=-0.0772
# Episode 76, loss=0.7156
# Episode 77, loss=-3.0801
# Episode 78, loss=0.5179
# Episode 79, loss=-3.9006
# Episode 80, loss=-4.8588
# Episode 81, loss=-10.7998
# Episode 82, loss=-2.3419
# Episode 83, loss=1.9552
# Episode 84, loss=1.9595
# Episode 85, loss=8.2620
# Episode 86, loss=2.2784
# Episode 87, loss=4.0685
# Episode 88, loss=-5.5579
# Episode 89, loss=-9.7391
# Episode 90, loss=-6.2922
# Episode 91, loss=-14.1471
# Episode 92, loss=-5.6248
# Episode 93, loss=2.2922
# Episode 94, loss=2.3228
# Episode 95, loss=-7.4855
# Episode 96, loss=-7.1156
# Episode 97, loss=5.4667
# Episode 98, loss=-0.2037
# Episode 99, loss=-4.9829
# Episode 100, loss=-1.4796
# Episode 101, loss=-11.6276
# Episode 102, loss=-0.1146
# Episode 103, loss=-16.4671
# Episode 104, loss=5.9688
# Episode 105, loss=9.9300
# Episode 106, loss=-11.6127
# Episode 107, loss=-1.2887
# Episode 108, loss=-16.2563
# Episode 109, loss=-15.3869
# Episode 110, loss=0.4383
# Episode 111, loss=-4.7737
# Episode 112, loss=8.6281
# Episode 113, loss=2.1223
# Episode 114, loss=-10.6076
# Episode 115, loss=1.4428
# Episode 116, loss=15.4070
# Episode 117, loss=-4.9315
# Episode 118, loss=-7.0170
# Episode 119, loss=2.0126
# Episode 120, loss=1.6696
# Episode 121, loss=-7.2717
# Episode 122, loss=5.7287
# Episode 123, loss=4.8733
# Episode 124, loss=-0.4392
# Episode 125, loss=-0.8326
# Episode 126, loss=-0.6393
# Episode 127, loss=-6.4508
# Episode 128, loss=-5.0294
# Episode 129, loss=3.5819
# Episode 130, loss=-0.9278
# Episode 131, loss=5.3367
# Episode 132, loss=-2.5915
# Episode 133, loss=-1.6513
# Episode 134, loss=-0.2699
# Episode 135, loss=-0.4661
# Episode 136, loss=1.9265
# Episode 137, loss=0.3230
# Episode 138, loss=-0.8392
# Episode 139, loss=-0.5156
# Episode 140, loss=0.6606
# Episode 141, loss=1.1065
# Episode 142, loss=-0.8624
# Episode 143, loss=2.1234
# Episode 144, loss=-3.6070
# Episode 145, loss=-3.5083
# Episode 146, loss=-1.2240
# Episode 147, loss=-1.9380
# Episode 148, loss=-1.7429
# Episode 149, loss=-5.3754
# Episode 150, loss=-0.0062
# Episode 151, loss=-1.6269
# Episode 152, loss=0.8024
# Episode 153, loss=-2.6055
# Episode 154, loss=1.7419
# Episode 155, loss=-7.4131
# Episode 156, loss=2.0477
# Episode 157, loss=-0.8532
# Episode 158, loss=3.9072
# Episode 159, loss=0.1066
# Episode 160, loss=-2.1477
# Episode 161, loss=-0.4682
# Episode 162, loss=-1.9984
# Episode 163, loss=-7.5727
# Episode 164, loss=3.0634
# Episode 165, loss=8.8410
# Episode 166, loss=6.5131
# Episode 167, loss=7.8214
# Episode 168, loss=-4.9351
# Episode 169, loss=-3.6372
# Episode 170, loss=5.6737
# Episode 171, loss=3.3345
# Episode 172, loss=-2.9075
# Episode 173, loss=7.7057
# Episode 174, loss=9.5293
# Episode 175, loss=3.1883
# Episode 176, loss=5.6586
# Episode 177, loss=-1.8016
# Episode 178, loss=-3.2593
# Episode 179, loss=-10.1460
# Episode 180, loss=-10.5715
# Episode 181, loss=-6.2832
# Episode 182, loss=-2.2971
# Episode 183, loss=11.4887
# Episode 184, loss=-1.4914
# Episode 185, loss=-6.1743
# Episode 186, loss=5.1211
# Episode 187, loss=-8.7284
# Episode 188, loss=-11.1280
# Episode 189, loss=3.2770
# Episode 190, loss=-0.5930
# Episode 191, loss=-11.4116
# Episode 192, loss=4.8948
# Episode 193, loss=-8.2385
# Episode 194, loss=8.6729
# Episode 195, loss=-4.7031
# Episode 196, loss=-1.4871
# Episode 197, loss=-1.1319
# Episode 198, loss=-2.8934
# Episode 199, loss=-14.7362
# Episode 200, loss=5.4759
# Episode 201, loss=-7.2027
# Episode 202, loss=2.4196
# Episode 203, loss=-0.0373
# Episode 204, loss=5.4232
# Episode 205, loss=-2.8479
# Episode 206, loss=0.4994
# Episode 207, loss=3.5714
# Episode 208, loss=5.3935
# Episode 209, loss=6.6803
# Episode 210, loss=-7.5264
# Episode 211, loss=13.7836
# Episode 212, loss=0.7426
# Episode 213, loss=-3.3446
# Episode 214, loss=-14.8954
# Episode 215, loss=-0.6461
# Episode 216, loss=-3.0573
# Episode 217, loss=6.4890
# Episode 218, loss=3.8350
# Episode 219, loss=-2.9463
# Episode 220, loss=-6.6713
# Episode 221, loss=3.4628
# Episode 222, loss=-13.1622
# Episode 223, loss=5.2533
# Episode 224, loss=7.8022
# Episode 225, loss=-7.2069
# Episode 226, loss=9.7685
# Episode 227, loss=12.1218
# Episode 228, loss=5.1012
# Episode 229, loss=-4.4778
# Episode 230, loss=-3.3419
# Episode 231, loss=-4.9417
# Episode 232, loss=9.1240
# Episode 233, loss=-10.5549
# Episode 234, loss=-7.0522
# Episode 235, loss=-5.2502
# Episode 236, loss=-10.6098
# Episode 237, loss=6.1767
# Episode 238, loss=3.8220
# Episode 239, loss=-5.5451
# Episode 240, loss=11.9040
# Episode 241, loss=-1.8827
# Episode 242, loss=6.1212
# Episode 243, loss=9.6007
# Episode 244, loss=1.8317
# Episode 245, loss=1.5693
# Episode 246, loss=4.9465
# Episode 247, loss=8.7571
# Episode 248, loss=-0.9923
# Episode 249, loss=5.7510
# Episode 250, loss=-11.6027
# Episode 251, loss=1.9238
# Episode 252, loss=2.9135
# Episode 253, loss=-5.7872
# Episode 254, loss=-7.3259
# Episode 255, loss=1.3878
# Episode 256, loss=-9.4277
# Episode 257, loss=3.7453
# Episode 258, loss=6.8131
# Episode 259, loss=3.0498
# Episode 260, loss=1.5236
# Episode 261, loss=-7.5489
# Episode 262, loss=-0.0632
# Episode 263, loss=-2.2868
# Episode 264, loss=0.8536
# Episode 265, loss=5.4955
# Episode 266, loss=4.4085
# Episode 267, loss=-6.4379
# Episode 268, loss=3.2199
# Episode 269, loss=-10.2894
# Episode 270, loss=3.9906
# Episode 271, loss=-2.8810
# Episode 272, loss=6.7702
# Episode 273, loss=-13.3648
# Episode 274, loss=1.1159
# Episode 275, loss=-7.7328
# Episode 276, loss=1.5413
# Episode 277, loss=-8.9230
# Episode 278, loss=1.4789
# Episode 279, loss=-2.6551
# Episode 280, loss=-8.2371
# Episode 281, loss=-6.6394
# Episode 282, loss=-7.1732
# Episode 283, loss=-4.2633
# Episode 284, loss=17.2707
# Episode 285, loss=18.3502
# Episode 286, loss=-4.1296
# Episode 287, loss=-3.0886
# Episode 288, loss=-0.8628
# Episode 289, loss=-7.4789
# Episode 290, loss=5.4364
# Episode 291, loss=4.0991
# Episode 292, loss=-9.9590
# Episode 293, loss=4.0150
# Episode 294, loss=4.5851
# Episode 295, loss=-12.9290
# Episode 296, loss=4.8917
# Episode 297, loss=10.3328
# Episode 298, loss=-2.1992
# Episode 299, loss=3.0872
# Episode 300, loss=7.1497
# Episode 1, loss=-3.2624
# Episode 2, loss=11.3900
# Episode 3, loss=-4.1870
# Episode 4, loss=6.0228
# Episode 5, loss=9.7200
# Episode 6, loss=-14.1282
# Episode 7, loss=-14.0062
# Episode 8, loss=-6.4095
# Episode 9, loss=-3.7987
# Episode 10, loss=3.2824
# Episode 11, loss=2.2706
# Episode 12, loss=-21.1446
# Episode 13, loss=4.0849
# Episode 14, loss=9.2742
# Episode 15, loss=7.5727
# Episode 16, loss=-8.0995
# Episode 17, loss=1.5264
# Episode 18, loss=2.9787
# Episode 19, loss=1.3377
# Episode 20, loss=-11.4765
# Episode 21, loss=-3.3535
# Episode 22, loss=0.1853
# Episode 23, loss=-2.4690
# Episode 24, loss=-7.5120
# Episode 25, loss=3.8534
# Episode 26, loss=-2.7312
# Episode 27, loss=-9.4824
# Episode 28, loss=4.6946
# Episode 29, loss=-5.5980
# Episode 30, loss=6.5795
# Episode 31, loss=2.9137
# Episode 32, loss=-7.1829
# Episode 33, loss=-8.5010
# Episode 34, loss=-9.8887
# Episode 35, loss=-9.2938
# Episode 36, loss=-2.9588
# Episode 37, loss=-1.7318
# Episode 38, loss=-6.4765
# Episode 39, loss=-4.1368
# Episode 40, loss=1.1330
# Episode 41, loss=15.9192
# Episode 42, loss=-1.8151
# Episode 43, loss=-5.3662
# Episode 44, loss=1.9719
# Episode 45, loss=1.2560
# Episode 46, loss=2.0381
# Episode 47, loss=-4.9014
# Episode 48, loss=6.0139
# Episode 49, loss=-4.9797
# Episode 50, loss=7.3469
# Episode 51, loss=-10.0493
# Episode 52, loss=-10.9978
# Episode 53, loss=-5.2471
# Episode 54, loss=-4.7001
# Episode 55, loss=2.1407
# Episode 56, loss=1.4335
# Episode 57, loss=-0.5339
# Episode 58, loss=1.7743
# Episode 59, loss=-5.7858
# Episode 60, loss=5.5234
# Episode 61, loss=-11.9231
# Episode 62, loss=2.5066
# Episode 63, loss=6.4521
# Episode 64, loss=0.4211
# Episode 65, loss=3.1059
# Episode 66, loss=2.0374
# Episode 67, loss=3.2685
# Episode 68, loss=2.8447
# Episode 69, loss=-7.6276
# Episode 70, loss=-5.3005
# Episode 71, loss=-2.3226
# Episode 72, loss=-1.7043
# Episode 73, loss=2.7780
# Episode 74, loss=-9.5558
# Episode 75, loss=-0.5082
# Episode 76, loss=-9.8942
# Episode 77, loss=-1.9267
# Episode 78, loss=8.9255
# Episode 79, loss=8.4401
# Episode 80, loss=8.0991
# Episode 81, loss=2.6401
# Episode 82, loss=8.1670
# Episode 83, loss=-0.3020
# Episode 84, loss=-2.0621
# Episode 85, loss=-4.7842
# Episode 86, loss=6.3074
# Episode 87, loss=-1.1347
# Episode 88, loss=-4.9046
# Episode 89, loss=-6.2233
# Episode 90, loss=-4.0538
# Episode 91, loss=0.6664
# Episode 92, loss=1.6916
# Episode 93, loss=4.1040
# Episode 94, loss=1.1016
# Episode 95, loss=-4.3505
# Episode 96, loss=-7.2751
# Episode 97, loss=-3.0226
# Episode 98, loss=3.4706
# Episode 99, loss=-9.0571
# Episode 100, loss=1.3032
# Episode 1, loss=3.6086
# Episode 2, loss=7.3352
# Episode 3, loss=1.4417
# Episode 4, loss=4.0405
# Episode 5, loss=-7.8135
# Episode 6, loss=0.5587
# Episode 7, loss=-0.9496
# Episode 8, loss=-3.8561
# Episode 9, loss=3.4318
# Episode 10, loss=-0.8854
# Episode 11, loss=4.3409
# Episode 12, loss=3.0931
# Episode 13, loss=-0.4303
# Episode 14, loss=-2.6084
# Episode 15, loss=-2.1499
# Episode 16, loss=3.0066
# Episode 17, loss=4.5564
# Episode 18, loss=-4.6672
# Episode 19, loss=4.7318
# Episode 20, loss=-2.9267
# Episode 21, loss=9.2993
# Episode 22, loss=2.7407
# Episode 23, loss=-5.3036
# Episode 24, loss=6.3916
# Episode 25, loss=3.1439
# Episode 26, loss=-3.7113
# Episode 27, loss=-2.2094
# Episode 28, loss=6.4799
# Episode 29, loss=0.6837
# Episode 30, loss=3.1884
# Episode 31, loss=-3.2315
# Episode 32, loss=2.2766
# Episode 33, loss=2.9595
# Episode 34, loss=3.3890
# Episode 35, loss=1.7745
# Episode 36, loss=6.8525
# Episode 37, loss=-2.1155
# Episode 38, loss=3.7908
# Episode 39, loss=0.4814
# Episode 40, loss=1.2204
# Episode 41, loss=4.7387
# Episode 42, loss=1.1550
# Episode 43, loss=0.1559
# Episode 44, loss=-3.4649
# Episode 45, loss=6.0180
# Episode 46, loss=2.8496
# Episode 47, loss=3.6615
# Episode 48, loss=-2.4203
# Episode 49, loss=12.0924
# Episode 50, loss=6.5794
# Episode 51, loss=0.9449
# Episode 52, loss=-2.1749
# Episode 53, loss=-1.1683
# Episode 54, loss=-2.7432
# Episode 55, loss=-6.7558
# Episode 56, loss=-0.0983
# Episode 57, loss=-0.1939
# Episode 58, loss=-12.0924
# Episode 59, loss=6.7851
# Episode 60, loss=-6.8609
# Episode 61, loss=-7.6560
# Episode 62, loss=6.4373
# Episode 63, loss=-7.6567
# Episode 64, loss=9.9580
# Episode 65, loss=-1.8947
# Episode 66, loss=-4.6523
# Episode 67, loss=9.8903
# Episode 68, loss=-13.5589
# Episode 69, loss=9.3781
# Episode 70, loss=-0.2927
# Episode 71, loss=6.9802
# Episode 72, loss=6.8788
# Episode 73, loss=3.0513
# Episode 74, loss=7.8035
# Episode 75, loss=-20.7577
# Episode 76, loss=9.1923
# Episode 77, loss=-21.3017
# Episode 78, loss=4.7490
# Episode 79, loss=7.5928
# Episode 80, loss=2.5582
# Episode 81, loss=6.4910
# Episode 82, loss=-3.9884
# Episode 83, loss=7.7882
# Episode 84, loss=9.3226
# Episode 85, loss=15.4662
# Episode 86, loss=5.9570
# Episode 87, loss=-2.0423
# Episode 88, loss=-11.8232
# Episode 89, loss=5.7973
# Episode 90, loss=-13.0804
# Episode 91, loss=7.6957
# Episode 92, loss=5.1649
# Episode 93, loss=5.5049
# Episode 94, loss=-1.0807
# Episode 95, loss=-4.7410
# Episode 96, loss=-0.1781
# Episode 97, loss=-8.0080
# Episode 98, loss=9.1328
# Episode 99, loss=3.0503
# Episode 100, loss=-6.7884

# %%
testing_loop_REINFORCE(1)
